# %% [markdown]
# Dr. Jesús Martí Gavilá. Departamento de Ingeniería Cartográfica, Geodesia y fotogrametría
# <font color="blue" ><h1 align=center>PRÁCTICA 10</h1> <p> <h1 align=center> EJERCICIO PRÁCTICO CON GOOGLE EARTH ENGINE PARA PYTHON</h1></font>
#
# <a href="http://www.upv.es/titulaciones/GTI/indexc.html"><img src = "http://www.upv.es/imagenes/marcaUPVN1.png" width =200 ></a>
#
# <h2 align=center>Grado Tecnologías Interactivas | Tecnologías de la Información Geográfica</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#  <b><H2>OBJETIVOS</h2></b>  <div align="justify">Utilizar la plataforma de Google Earth Engine donde el alumno, de forma autónoma, obtenga los valores del Indice Medioambiental asignado, en función de dos constelaciones de satélites y sea plasmado en una WebMapping</div>
# <h2>Resultados:</h2>
#     <ul>
#         <li>Crear un WebMapping con los resultados de los índices cálculados </li>
#         <li>Exportar las imágenes en formato Geotiff a Drive, de la zona de estudio</li>
#     </ul>

# %% [markdown]
# <h2><font color="blue" >Librerías y Activación GEE</font></h2><p>
#
# Cargar las librerías necesarias y activar la plataforma de GEE en la que previamenete el usuario deberá haberse registrado (solo se realiza una única vez por maquina)

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting folium
#   Downloading folium-0.15.1-py2.py3-none-any.whl (97 kB)
# Collecting branca>=0.6.0
#   Downloading branca-0.7.0-py3-none-any.whl (25 kB)
# Collecting xyzservices
#   Downloading xyzservices-2023.10.1-py3-none-any.whl (56 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.7.0 folium-0.15.1 xyzservices-2023.10.1

# %%
import folium
from folium import plugins
import ee
import branca
import branca.colormap as cm
ee.Authenticate() # Si ya se está autentificado anteriormente en esta maquina, este paso no es necesario
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=SOPDftk5VYHgunet8PEhQWL47yHAmosYbm3ek8QneFA&tc=YG5285fWPNb8uJ-kNSoCQXCPl-aYhTfrxfdwRWEtzfw&cc=pDm-CZQGPhBDcmdCg3B3U-UbhkVvEGZAeI3nurp2bF4>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=SOPDftk5VYHgunet8PEhQWL47yHAmosYbm3ek8QneFA&tc=YG5285fWPNb8uJ-kNSoCQXCPl-aYhTfrxfdwRWEtzfw&cc=pDm-CZQGPhBDcmdCg3B3U-UbhkVvEGZAeI3nurp2bF4</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AfJohXmoigEvZy0OKC4UJp1BjwBwbwPiPPAz4hNhyqMXZWW4NaRMq7CvngM
#
# Successfully saved authorization token.

# %%
# Función de GEE predefinida para añadir capas con Folium

def add_ee_layer (self, ee_imagen, parametros, nombre):
    map_id = ee.Image(ee_imagen).getMapId(parametros)
    folium.raster_layers.TileLayer(
        tiles=map_id['tile_fetcher'].url_format, 
        attr = 'ALUMNOS......Tecnologias de la Informacion Geografica', #Indicar el nombre de los componentes del grupo
        name = nombre,
        overlay = True, # Permite la superposición
        control = True # Permite que aparezca la capa o no en el layer control
        ).add_to(self)

# Con esto creamos un método propio llamado addLayer que llamara a la función add_ee_layer
folium.Map.addLayer = add_ee_layer

# %%
# Leyenda
colormap = cm.StepColormap(['red','yellow','green','blue'], index=[-1,-0.3,0,0.2,1],vmin=-1, vmax=1, max_labels=5,caption='Valores del NDWI y MNDWI',tick_labels=[])

# mapa.add_child(colormap) ............Utilizar esta expresión para añadir la rampa al mapa
colormap
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="12" y1="15" x2="12" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="13" y1="15" x2="13" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="14" y1="15" x2="14" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="15" y1="15" x2="15" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="16" y1="15" x2="16" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="17" y1="15" x2="17" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="18" y1="15" x2="18" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="19" y1="15" x2="19" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="20" y1="15" x2="20" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="21" y1="15" x2="21" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="22" y1="15" x2="22" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="23" y1="15" x2="23" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="24" y1="15" x2="24" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="25" y1="15" x2="25" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="26" y1="15" x2="26" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="27" y1="15" x2="27" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="28" y1="15" x2="28" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="29" y1="15" x2="29" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="30" y1="15" x2="30" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="31" y1="15" x2="31" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="32" y1="15" x2="32" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="33" y1="15" x2="33" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="34" y1="15" x2="34" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="35" y1="15" x2="35" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="36" y1="15" x2="36" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="37" y1="15" x2="37" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="38" y1="15" x2="38" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="39" y1="15" x2="39" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="40" y1="15" x2="40" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="41" y1="15" x2="41" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="42" y1="15" x2="42" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="43" y1="15" x2="43" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="44" y1="15" x2="44" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="45" y1="15" x2="45" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="46" y1="15" x2="46" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="47" y1="15" x2="47" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="48" y1="15" x2="48" y2="27" style="stroke:#ff0000ff;stroke-width:2;" /><line x1="49" y1="15"  ...

# %% [markdown]
# <h1 align=center><font color="green" >Estudio de Indices de AGUA con Google Earth Engine.</font></h1><p>
#
# <h2 align=center> Caso de estudio </h2><p>
# <h4 align=center>
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</h4>

# %% [markdown]
# <div align="justify"> </div>El método Índice de agua de diferencia normalizada (NDWI, por sus siglas en inglés) es un índice que sirve para definir y monitorizar los cambios de contenido en aguas superficiales.

# %% [markdown]
# <h2><font color="red" >TAREA 1</font></h2><p>
# <h3> Calcular el Indice con imágenes satélite de la plataformas correspondiente al grupo asignado</h3> <p>
# Se calculará el Indice con las imágenes satélite de 2 plataformas para un periodo de tiempo establecido y un lugar de estudio, en función del grupo de estudio asignado.<p>
# Se realizará un WebMap con las 2 capas resultantes, aplicando la rampa de colores índicada anteriormente y se exportará en formato Geotiff, al Drive del grupo, las imagenes correspondientes a las zonas de estudio indicadas.
# <p><h3 align=center> Índice de Agua de Diferencia Normalizada (NDWI). McFeeters, 1996</h3> <p><p>
# <h3 align=center>Índice de Agua de Diferencia Normalizada Modificado (MNDWI). Xu, 2006</h3><p>

# %% [markdown]
# <h2 align=center>Valores rampa de colores</h2>

# %% [markdown]
# ![RAMPA.PNG](attachment:RAMPA.PNG)

# %%
# Colección de imágenes con una nubosidad inferior al 20% y la medía calculada de los pixels
landsat_2022= (ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')
                  .filterDate('2022-03-21', '2022-06-21')
                  .filter(ee.Filter.lt('CLOUD_COVER',20)).mean()) #el filtro de nubosidad varía según imagen

landsat_2023= (ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')
                  .filterDate('2023-03-21', '2023-06-21')
                  .filter(ee.Filter.lt('CLOUD_COVER',20)).mean())


# Funciones de cálculo MNDWI

def MNDWI(image):
    MNDWI = image.expression('(GREEN - SWIR) / (GREEN + SWIR)',{
            'GREEN': image.select('SR_B3').multiply(0.0000275).add(-0.2),
            'SWIR' : image.select('SR_B6').multiply(0.0000275).add(-0.2),
        })
    return MNDWI

def add_ee_layer (self, ee_imagen, parametros, nombre):
    map_id = ee.Image(ee_imagen).getMapId(parametros)
    folium.raster_layers.TileLayer(
        tiles=map_id['tile_fetcher'].url_format, 
        attr = 'ALUMNOS......Tecnologias de la Informacion Geografica', #Indicar el nombre de los componentes del grupo
        name = nombre,
        overlay = True, # Permite la superposición
        control = True # Permite que aparezca la capa o no en el layer control
        ).add_to(self)

# Con esto creamos un método propio llamado addLayer que llamara a la función add_ee_layer
folium.Map.addLayer = add_ee_layer

# Parámetros de visualización de la imágen
sld_intervalos = """
    <RasterSymbolizer>
        <ColorMap type="intervals" extended="false" >
            <ColorMapEntry color="#FF0000" quantity="-0.3" label="Superficies sin agua"/>
            <ColorMapEntry color="#FFD167" quantity="0" label="Sequia moderada" />
            <ColorMapEntry color="#008f39" quantity="0.2" label="Inundación, humedad" />
            <ColorMapEntry color="#0000ff" quantity="1.0" label="Superficie de agua" />
        </ColorMap>
    </RasterSymbolizer>"""


MNDWI_2022 = MNDWI(landsat_2022)
MNDWI_2023 = MNDWI(landsat_2023)

# Exportar imagen a Google Drive. Configuración parámetros de salida
geometry = ee.Geometry.Rectangle([ 31.572513, -8.675228, -32.935886, 7.371385  ]) # Coordenadas geográficas minima y maxima de la imagen a exportar


task_config = {
        'region': geometry,
        'fileFormat': 'GeoTIFF',
        'fileNamePrefix': 'Chenyi_Ruiyu_MNDWI2022_ld08',
        'folder':'gee-datos',
        'scale': 20,      # Resolución en metros del pixel 
        'crs': 'EPSG:4326',
        'image':MNDWI_2022 ,
        'description': 'Imagen procesada MNDWI'
    }

ee.batch.Export.image.toDrive(**task_config).start()



# Crear y añadir elementos al mapa
# Leyenda
colormap = cm.StepColormap(['red','yellow','green','blue'], index=[-1,-0.3,0,0.2,1],vmin=-1, vmax=1, max_labels=5,caption='Valores del NDWI y MNDWI',tick_labels=[])

# mapa.add_child(colormap) ............Utilizar esta expresión para añadir la rampa al mapa
colormap
mapa_MNDWI = folium.Map(location=[-7.971902, 32.246431], zoom_start=8)
mapa_MNDWI.addLayer(MNDWI_2022.sldStyle(sld_intervalos),None,'SLD intervalos'),
mapa_MNDWI.addLayer(MNDWI_2023.sldStyle(sld_intervalos),None,'SLD intervalos')
mapa_MNDWI.add_child(colormap)
folium.LayerControl().add_to(mapa_MNDWI)

mapa_MNDWI
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e
# %%
# Colección de imágenes con una nubosidad inferior al 20% y la medía calculada de los pixels
landsat_2022= (ee.ImageCollection('LANDSAT/LC09/C02/T1_L2')
                  .filterDate('2022-03-21', '2022-06-21')
                  .filter(ee.Filter.lt('CLOUD_COVER',20)).mean()) #el filtro de nubosidad varía según imagen

landsat_2023= (ee.ImageCollection('LANDSAT/LC09/C02/T1_L2')
                  .filterDate('2023-03-21', '2023-06-21')
                  .filter(ee.Filter.lt('CLOUD_COVER',20)).mean())


# Funciones de cálculo MNDWI

def MNDWI(image):
    MNDWI = image.expression('(GREEN - SWIR) / (GREEN + SWIR)',{
            'GREEN': image.select('SR_B3').multiply(0.0000275).add(-0.2),
            'SWIR' : image.select('SR_B6').multiply(0.0000275).add(-0.2),
        })
    return MNDWI

def add_ee_layer (self, ee_imagen, parametros, nombre):
    map_id = ee.Image(ee_imagen).getMapId(parametros)
    folium.raster_layers.TileLayer(
        tiles=map_id['tile_fetcher'].url_format, 
        attr = 'ALUMNOS......Tecnologias de la Informacion Geografica', #Indicar el nombre de los componentes del grupo
        name = nombre,
        overlay = True, # Permite la superposición
        control = True # Permite que aparezca la capa o no en el layer control
        ).add_to(self)

# Con esto creamos un método propio llamado addLayer que llamara a la función add_ee_layer
folium.Map.addLayer = add_ee_layer

# Parámetros de visualización de la imágen
sld_intervalos = """
    <RasterSymbolizer>
        <ColorMap type="intervals" extended="false" >
            <ColorMapEntry color="#FF0000" quantity="-0.3" label="Superficies sin agua"/>
            <ColorMapEntry color="#FFD167" quantity="0" label="Sequia moderada" />
            <ColorMapEntry color="#008f39" quantity="0.2" label="Inundación, humedad" />
            <ColorMapEntry color="#0000ff" quantity="1.0" label="Superficie de agua" />
        </ColorMap>
    </RasterSymbolizer>"""


MNDWI_2022 = MNDWI(landsat_2022)
MNDWI_2023 = MNDWI(landsat_2023)

# Exportar imagen a Google Drive. Configuración parámetros de salida
geometry = ee.Geometry.Rectangle([ 31.572513, -8.675228, -32.935886, 7.371385  ]) # Coordenadas geográficas minima y maxima de la imagen a exportar


task_config = {
        'region': geometry,
        'fileFormat': 'GeoTIFF',
        'fileNamePrefix': 'Chenyi_Ruiyu_MNDWI2022_ld08',
        'folder':'gee-datos',
        'scale': 20,      # Resolución en metros del pixel 
        'crs': 'EPSG:4326',
        'image':MNDWI_2022 ,
        'description': 'Imagen procesada MNDWI'
    }

ee.batch.Export.image.toDrive(**task_config).start()



# Crear y añadir elementos al mapa
# Leyenda
colormap = cm.StepColormap(['red','yellow','green','blue'], index=[-1,-0.3,0,0.2,1],vmin=-1, vmax=1, max_labels=5,caption='Valores del NDWI y MNDWI',tick_labels=[])

# mapa.add_child(colormap) ............Utilizar esta expresión para añadir la rampa al mapa
colormap
mapa_MNDWI = folium.Map(location=[-7.971902, 32.246431], zoom_start=8.6)
mapa_MNDWI.addLayer(MNDWI_2022.sldStyle(sld_intervalos),None,'SLD intervalos'),
mapa_MNDWI.addLayer(MNDWI_2023.sldStyle(sld_intervalos),None,'SLD intervalos')
mapa_MNDWI.add_child(colormap)
folium.LayerControl().add_to(mapa_MNDWI)

mapa_MNDWI
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1954e27b4e54e29fb34f410e1b7ed4ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1954e27b4e54e29fb34f410e1b7ed4ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_