# %% [markdown]
# <h4 align=center>Dr. Jesús Martí Gavilá. Departamento de Ingeniería Cartográfica, Geodesia y fotogrametría </h4>
# <font color="blue" ><h1 align=center>PRÁCTICA 11</h1> <p> <h1 align=center> CURSO BÁSICO PYTHON: GEOTIFF, SHAPE Y PLUGINS FOLIUM</h1></font>
#
# <a href="http://www.upv.es/titulaciones/GTI/indexc.html"><img src = "http://www.upv.es/imagenes/marcaUPVN1.png" width =200 ></a>
#
# <h2 align=center>Grado Tecnologías Interactivas | Tecnologías de la Información Geográfica</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <b>FOLIUM</b> es una biblioteca de visualización de Python que se desarrolló con el único fin de visualizar datos geoespaciales. Es una biblioteca completamente gratuita. <p>
# <h2>Tabla de Contenido</h2>
#     <ul>
#         <li>
#             Datos Raster
#         </li>
#         <li>
#             Datos Vectoriales
#         </li>
#         <li>
#             Plugins
#         </li>
#     </ul>
# <p>
# <b> Documentación: </b> <a href="https://python-visualization.github.io/folium/"> https://python-visualization.github.io/folium/</a><p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ul>
# <b>RECOMENDACIONES</b><p><li>Comprobar la versión de python del pluging para el que está creado. </li><p><li> Utilizar  (pip install -U "LIBRERIA") para que instale la última versión adecuada a vuestro enviroment.</li><p>
#     <li>Si no funciona PIP, utilizar la otra ópcion: (conda install c conda-forge "LIBRERIA")</li>
#     </ul>

# %%
# !pip install -U rasterio
# !pip install -U geopandas
# Out:
# Requirement already satisfied: rasterio in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (1.3.9)
# Requirement already satisfied: affine in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from rasterio) (23.1.0)
# Requirement already satisfied: certifi in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from rasterio) (2023.11.17)
# Requirement already satisfied: click>=4.0 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from rasterio) (1.26.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from rasterio) (68.0.0)
# Requirement already satisfied: colorama in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from snuggs>=1.4.1->rasterio) (3.1.1)
# ^C

# %%
import folium
from folium import plugins
import rasterio
import numpy
from matplotlib import cm
import geopandas as gpd
import pandas as pd
import branca
# Out:
# Requirement already satisfied: geopandas in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (0.14.2)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from geopandas) (2.1.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from fiona>=1.8.21->geopandas) (2023.11.17)
# Requirement already satisfied: click~=8.0 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from fiona>=1.8.21->geopandas) (68.0.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from pandas>=1.4.0->geopandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\54480.ruiyu_chen\anaconda3\envs\geomatica\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)

# %% [markdown]
# <h2><font color="blue" > DATOS RASTER </font></h2><p>

# %%
# Creamos el mapa
mapa_raster = folium.Map(location=(39,-0.25), tiles = 'OpenStreetMap', zoom_start = 11)

# Función cargar Geotiff
def geotiff (imagen, nombre):
    # Formateamos la imagen
    ds = rasterio.open(imagen)
    c = ds.bounds
    datos = ds.read()
    datos = numpy.moveaxis(datos,(0,1,2),(2,0,1))

    # Creamos la imagen y la añadimos al mapa
    folium.raster_layers.ImageOverlay(
        image=datos,
        name=nombre,
        bounds=[[c.bottom, c.left],[c.top, c.right]],
        colormap=cm.RdYlGn,       # https://matplotlib.org/stable/gallery/color/colormap_reference.html
        ).add_to(mapa_raster)

# Función Cargar un PNG    
def png (imagen,nombre):
    folium.raster_layers.ImageOverlay(
        image=imagen,
        name=nombre,
        bounds=[[38.9, -0.4], [39.1, -0.2]],
       ).add_to(mapa_raster)
    
    
# Llamada a las funciones
geotiff("ZONA_QUEMADA.TIF", "zona_quemada")
#png("RASTER/SAVI_POST.png", "SAVI_POST")

# Exportamos el mapa
folium.LayerControl().add_to(mapa_raster)
mapa_raster.save('practica5.html')
mapa_raster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f557f1960f6a2b8dcdce593e3368a649 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f557f1960f6a2b8dcdce593e3368a649&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f557f1960f6a2b8dcdce593e3368a649 = L.map(
#                 &quot;map_f557f1960f6a2b8dcdce593e3368a649&quot;,
#                 {
#                     center: [39.0, -0.25],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21c7e6654d2200b373d6bc0aa68d2ace = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_21c7e6654d2200b373d6bc0aa68d2ace.addTo(map_f557f1960f6a2b8dcdce593e3368a649);
#
#             var image_overlay_3d87aae48916b638f62183b522971011 = L.imageOverlay(
#                 &quot;data:image/png;base64,...&quot;,
#                 [[4312000.0, 726000.0], [4326000.0, 740000.0]],
#                 {}
#             );
#
#
#                 image_overlay_3d87aae48916b638f62183b522971011.addTo(map_f557f1960f6a2b8dcdce593e3368a649);
#
#             var layer_control_bfa6fcc311ae35f9935773897efcac85_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_21c7e6654d2200b373d6bc0aa68d2ace,
#                 },
#                 overlays :  {
#                     &quot;zona_quemada&quot; : image_overlay_3d87aae48916b638f62183b522971011,
#                 },
#             };
#             let layer_control_bfa6fcc311ae35f9935773897efcac85 = L.control.layers(
#                 layer_control_bfa6fcc311ae35f9935773897efcac85_layers.base_layers,
#                 layer_control_bfa6fcc311ae35f9935773897efcac85_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_f557f1960f6a2b8dcdce593e3368a649);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h2><font color="blue" > DATOS VECTORIALES </font></h2><p>

# %%
#práctica 4
# Creamos el mapa
mapa_vec = folium.Map(location=(43,-7), tiles = 'OpenStreetMap', zoom_start = 6.8)

# Lectura y transformación del Shape

gpd.read_file('ZONAS_VALIDAS.shp').to_file('zonas_validas_prac4.geojson', driver='GeoJSON')
json = gpd.read_file('zonas_validas_prac4.geojson')

# añadimos elementos al mapa

# Macador con la Aptitud del polígono
popup = folium.GeoJsonPopup(
    fields=["DN"],
    aliases=["Aptitud"],
    localize=True,
    labels=True,
    style="background-color: yellow;",
)

#Rampa de colores en función de los valores de Aptitud
colormap = branca.colormap.StepColormap(
    vmin=1,
    vmax=3,
    colors=["red", "yellow", "green"],
    caption="Aptitud de la zona",
)

#Capa a representar con la simbología índicada en la rampa
g = folium.GeoJson(
    json,
    style_function=lambda x: {
        "fillColor": colormap(x["properties"]["DN"]),
        "fillOpacity":0.7,
        "color": "black",
        "weight": 0.2},
    name='Galicia_Ecualiptus',
    popup=popup,
).add_to(mapa_vec)
    
# Control de capas
folium.LayerControl().add_to(mapa_vec)

mapa_vec
mapa_vec.save('practica4_html.html')

# %% [markdown]
# <h2><font color="blue" > PLUGINS </font></h2><p>
#
#
# <b> Diferentes plugins de Folium: </b> <a href="https://python-visualization.github.io/folium/plugins.html"> https://python-visualization.github.io/folium/plugins.html </a>
# <p>

# %%
# Herramientas de dibujo
plugins.Draw(export=True).add_to(mapa_vec)

# Minimap
plugins.MiniMap(width=200, height=100, toggle_display=True ).add_to(mapa_vec)

# Localización usuario
plugins.LocateControl().add_to(mapa_vec)

# Coordenadas de ubicación
formato = "function(num) {return L.Util.formatNum(num, 3) + ' º ';};"
plugins.MousePosition(
    position="topright",
    separator=" | ",
    empty_string="NaN",
    lng_first=True,
    num_digits=20,
    prefix="Coordenadas:",
    lat_formatter=formato,
    lng_formatter=formato,
).add_to(mapa_vec)

# Zoom pantalla completa
plugins.Fullscreen().add_to(mapa_vec)

# Leyenda
legend_html = """
{% macro html(this, kwargs) %}
<div style="
    position: fixed;
    bottom: 50px;
    left: 50px;
    width: 250px;
    height: 80px;
    z-index:9999;
    font-size:14px;
    ">
    <p><a style="color:#008000;font-size:150%;margin-left:20px;">◼</a>&emsp;Aptitud Alta</p>
    <p><a style="color:#FFFF00;font-size:150%;margin-left:20px;">◼</a>&emsp;Aptitud media</p>
    <p><a style="color:#FF0000;font-size:150%;margin-left:20px;">◼</a>&emsp;Aptitud baja</p>
</div>

{% endmacro %}
"""

legend = branca.element.MacroElement()
legend._template = branca.element.Template(legend_html)
mapa_vec.add_child(legend)

mapa_vec.save("mapa_vectorial.html")
mapa_vec

# %% [markdown]
# ### Busqueda de elementos

# %%
# Generar la base de datos
accidentes_Madrid = folium.Map(location=(40.43,-3.65), tiles = 'OpenStreetMap', zoom_start = 12)
accidentes_df = pd.read_csv('BASE_DATOS/2020_Accidentalidad.csv')
acci_df=accidentes_df.loc[(accidentes_df['tipo_persona']=='Conductor') & (accidentes_df['tipo_vehiculo']=='Turismo')] 

# Repressentar la información
accidentes = plugins.MarkerCluster( name="Accidentes",).add_to(accidentes_Madrid)

for lat, lng, label, in zip(acci_df.latitud, acci_df.longitud, acci_df['num_expediente']): 
    folium.Marker(
        location = [lat, lng],
        icon = folium.Icon(color="orange", icon="fa-car", prefix = 'fa'),
        popup = label,
        name = label, # Nombre del objeto para su posterior indetinficación
        ).add_to(accidentes)

# Buscar Registros
buscar_acci = plugins.Search(
        layer = accidentes,
        geom_type = 'Point',
        collapsed = False,
        search_label = 'name', # Nombre del objeto
        placeholder = 'Num_Expediente',
        ).add_to(accidentes_Madrid)

# Plugins
plugins.MiniMap().add_to(accidentes_Madrid)

# Exportar a HTML
accidentes_Madrid.save("HTML/accidentes.html")
accidentes_Madrid

# %%
# Agrega un cuadro de búsqueda al mapa para buscar características geográficas como ciudades, países, etc. Puede buscar con nombres o direcciones.

# Usar normativa de OpenStreetMap https://operations.osmfoundation.org/policies/nominatim/
mapa_2 = folium.Map(location=(43,-8), tiles = 'OpenStreetMap', zoom_start = 8)

plugins.Geocoder().add_to(mapa_2)

mapa_2
